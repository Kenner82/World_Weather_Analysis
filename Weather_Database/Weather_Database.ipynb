# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# %%
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 759

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE  
        
             
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        # Append the city information into the city_data list
        # YOUR CODE HERE
        
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avera
# Processing Record 2 of Set 1 | ankara
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | hailar
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | pisco
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | malegaon
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | voyvozh
# Processing Record 14 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 1 | kaeo
# Processing Record 16 of Set 1 | amapa
# Processing Record 17 of Set 1 | mahibadhoo
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | bandarbeyla
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | tairua
# Processing Record 22 of Set 1 | skelleftea
# Processing Record 23 of Set 1 | guerrero negro
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | vista hermosa
# Processing Record 26 of Set 1 | filingue
# Processing Record 27 of Set 1 | hofn
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | ayan
# Processing Record 31 of Set 1 | faanui
# Processing Record 32 of Set 1 | ponta do sol
# Processing Record 33 of Set 1 | tambopata
# Processing Record 34 of Set 1 | cayenne
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | dikson
# Processing Record 40 of Set 1 | biasca
# Processing Record 41 of Set 1 | necochea
# Processing Record 42 of Set 1 | kavieng
# Processing Record 43 of Set 1 | brumadinho
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | athabasca
# Processing Record 47 of Set 1 | solin
# Processing Record 48 of Set 1 | meulaboh
# Processing Record 49 of Set 1 | chokurdakh
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | sorland
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | panguna
# Processing Record 5 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | rosamorada
# Processing Record 8 of Set 2 | ixtapa
# Processing Record 9 of Set 2 | port lincoln
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 2 | vanimo
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | marabba
# Processing Record 17 of Set 2 | kattivakkam
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | elizabeth city
# Processing Record 20 of Set 2 | norman wells
# Processing Record 21 of Set 2 | nouakchott
# Processing Record 22 of Set 2 | oksfjord
# Processing Record 23 of Set 2 | migori
# Processing Record 24 of Set 2 | lebu
# Processing Record 25 of Set 2 | saskylakh
# Processing Record 26 of Set 2 | pitimbu
# Processing Record 27 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 2 | thunder bay
# Processing Record 29 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 2 | feijo
# Processing Record 31 of Set 2 | lavrentiya
# Processing Record 32 of Set 2 | outlook
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | samarinda
# Processing Record 36 of Set 2 | fortuna
# Processing Record 37 of Set 2 | nara
# Processing Record 38 of Set 2 | luderitz
# Processing Record 39 of Set 2 | chuy
# Processing Record 40 of Set 2 | puerto cabezas
# Processing Record 41 of Set 2 | khani
# Processing Record 42 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 2 | kahului
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | tucuman
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | nemuro
# Processing Record 49 of Set 2 | san pedro
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | faya
# Processing Record 2 of Set 3 | tsibanobalka
# Processing Record 3 of Set 3 | codrington
# Processing Record 4 of Set 3 | topolobampo
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | flinders
# Processing Record 7 of Set 3 | del rio
# Processing Record 8 of Set 3 | viedma
# Processing Record 9 of Set 3 | innisfail
# Processing Record 10 of Set 3 | barpeta
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | salalah
# Processing Record 13 of Set 3 | hervey bay
# Processing Record 14 of Set 3 | hobart
# Processing Record 15 of Set 3 | vrbove
# Processing Record 16 of Set 3 | san patricio
# Processing Record 17 of Set 3 | touros
# Processing Record 18 of Set 3 | tiksi
# Processing Record 19 of Set 3 | tsiroanomandidy
# Processing Record 20 of Set 3 | kyzyl-suu
# Processing Record 21 of Set 3 | bengkulu
# Processing Record 22 of Set 3 | saint-augustin
# Processing Record 23 of Set 3 | kushima
# Processing Record 24 of Set 3 | san luis
# Processing Record 25 of Set 3 | kasongo-lunda
# Processing Record 26 of Set 3 | am timan
# Processing Record 27 of Set 3 | atuona
# Processing Record 28 of Set 3 | san juan
# Processing Record 29 of Set 3 | sitka
# Processing Record 30 of Set 3 | podor
# Processing Record 31 of Set 3 | ito
# Processing Record 32 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 3 | klaksvik
# Processing Record 34 of Set 3 | vaini
# Processing Record 35 of Set 3 | salinas
# Processing Record 36 of Set 3 | santa luzia
# Processing Record 37 of Set 3 | guipavas
# Processing Record 38 of Set 3 | constantine
# Processing Record 39 of Set 3 | port alfred
# Processing Record 40 of Set 3 | carutapera
# Processing Record 41 of Set 3 | kodiak
# Processing Record 42 of Set 3 | ostrovnoy
# Processing Record 43 of Set 3 | laguna
# Processing Record 44 of Set 3 | saint-philippe
# Processing Record 45 of Set 3 | xuzhou
# Processing Record 46 of Set 3 | likasi
# Processing Record 47 of Set 3 | linxia
# Processing Record 48 of Set 3 | hermanus
# Processing Record 49 of Set 3 | svetlogorsk
# Processing Record 50 of Set 3 | husainabad
# Processing Record 1 of Set 4 | jumla
# Processing Record 2 of Set 4 | coos bay
# Processing Record 3 of Set 4 | axim
# Processing Record 4 of Set 4 | mangai
# Processing Record 5 of Set 4 | mont-de-marsan
# Processing Record 6 of Set 4 | aswan
# Processing Record 7 of Set 4 | komsomolskiy
# Processing Record 8 of Set 4 | quatre cocos
# Processing Record 9 of Set 4 | camopi
# Processing Record 10 of Set 4 | coahuayana
# Processing Record 11 of Set 4 | souillac
# Processing Record 12 of Set 4 | sattenapalle
# Processing Record 13 of Set 4 | avarua
# Processing Record 14 of Set 4 | kiruna
# Processing Record 15 of Set 4 | tuxpan
# Processing Record 16 of Set 4 | airai
# Processing Record 17 of Set 4 | wanning
# Processing Record 18 of Set 4 | beira
# Processing Record 19 of Set 4 | coquimbo
# Processing Record 20 of Set 4 | hluti
# Processing Record 21 of Set 4 | tanda
# Processing Record 22 of Set 4 | dakar
# Processing Record 23 of Set 4 | rumoi
# Processing Record 24 of Set 4 | canton
# Processing Record 25 of Set 4 | jamestown
# Processing Record 26 of Set 4 | hasaki
# Processing Record 27 of Set 4 | esperance
# Processing Record 28 of Set 4 | vestmannaeyjar
# Processing Record 29 of Set 4 | yarada
# Processing Record 30 of Set 4 | jawhar
# Processing Record 31 of Set 4 | dvurechensk
# Processing Record 32 of Set 4 | nadym
# Processing Record 33 of Set 4 | mitu
# Processing Record 34 of Set 4 | stawell
# Processing Record 35 of Set 4 | mandali
# Processing Record 36 of Set 4 | hithadhoo
# Processing Record 37 of Set 4 | nalut
# Processing Record 38 of Set 4 | port elizabeth
# Processing Record 39 of Set 4 | kusti
# Processing Record 40 of Set 4 | mehamn
# Processing Record 41 of Set 4 | baruun-urt
# Processing Record 42 of Set 4 | tiarei
# Processing Record 43 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 4 | ancud
# Processing Record 46 of Set 4 | qeshm
# Processing Record 47 of Set 4 | katsuura
# Processing Record 48 of Set 4 | nhulunbuy
# Processing Record 49 of Set 4 | unity
# Processing Record 50 of Set 4 | muros
# Processing Record 1 of Set 5 | thinadhoo
# Processing Record 2 of Set 5 | carnarvon
# Processing Record 3 of Set 5 | victoria
# Processing Record 4 of Set 5 | san cristobal
# Processing Record 5 of Set 5 | westport
# Processing Record 6 of Set 5 | tasiilaq
# Processing Record 7 of Set 5 | verdalsora
# City not found. Skipping...
# Processing Record 8 of Set 5 | te anau
# Processing Record 9 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 5 | choix
# Processing Record 11 of Set 5 | sinnamary
# Processing Record 12 of Set 5 | amuntai
# Processing Record 13 of Set 5 | liverpool
# Processing Record 14 of Set 5 | castro
# Processing Record 15 of Set 5 | ovalle
# Processing Record 16 of Set 5 | haapiti
# Processing Record 17 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 18 of Set 5 | saint-pierre
# Processing Record 19 of Set 5 | becerril
# Processing Record 20 of Set 5 | kourou
# Processing Record 21 of Set 5 | gat
# Processing Record 22 of Set 5 | leningradskiy
# Processing Record 23 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 5 | trairi
# Processing Record 25 of Set 5 | valdivia
# Processing Record 26 of Set 5 | norrtalje
# Processing Record 27 of Set 5 | kayerkan
# Processing Record 28 of Set 5 | seoul
# Processing Record 29 of Set 5 | ventspils
# Processing Record 30 of Set 5 | saint george
# Processing Record 31 of Set 5 | pevek
# Processing Record 32 of Set 5 | bethel
# Processing Record 33 of Set 5 | ponta delgada
# Processing Record 34 of Set 5 | of
# City not found. Skipping...
# Processing Record 35 of Set 5 | lima
# Processing Record 36 of Set 5 | riverton
# Processing Record 37 of Set 5 | millbrook
# Processing Record 38 of Set 5 | leander
# Processing Record 39 of Set 5 | springdale
# Processing Record 40 of Set 5 | khasan
# Processing Record 41 of Set 5 | sinegorye
# Processing Record 42 of Set 5 | kalmunai
# Processing Record 43 of Set 5 | vestmanna
# Processing Record 44 of Set 5 | flin flon
# Processing Record 45 of Set 5 | ngunguru
# Processing Record 46 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 5 | kyra
# Processing Record 49 of Set 5 | bathsheba
# Processing Record 50 of Set 5 | college
# Processing Record 1 of Set 6 | tabou
# Processing Record 2 of Set 6 | narsaq
# Processing Record 3 of Set 6 | novyy urgal
# Processing Record 4 of Set 6 | monrovia
# Processing Record 5 of Set 6 | nuqui
# Processing Record 6 of Set 6 | hobyo
# Processing Record 7 of Set 6 | los llanos de aridane
# Processing Record 8 of Set 6 | marawi
# Processing Record 9 of Set 6 | srednekolymsk
# Processing Record 10 of Set 6 | terney
# Processing Record 11 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 6 | los alamos
# Processing Record 13 of Set 6 | yulara
# Processing Record 14 of Set 6 | lahat
# Processing Record 15 of Set 6 | port macquarie
# Processing Record 16 of Set 6 | saldanha
# Processing Record 17 of Set 6 | sendafa
# Processing Record 18 of Set 6 | erdenet
# Processing Record 19 of Set 6 | bjornevatn
# Processing Record 20 of Set 6 | chifeng
# Processing Record 21 of Set 6 | awka
# Processing Record 22 of Set 6 | thompson
# Processing Record 23 of Set 6 | verkhnevilyuysk
# Processing Record 24 of Set 6 | sao filipe
# Processing Record 25 of Set 6 | margate
# Processing Record 26 of Set 6 | balkhash
# Processing Record 27 of Set 6 | moindou
# Processing Record 28 of Set 6 | naze
# Processing Record 29 of Set 6 | boa vista
# Processing Record 30 of Set 6 | nicoya
# Processing Record 31 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 6 | limbang
# Processing Record 33 of Set 6 | ponazyrevo
# Processing Record 34 of Set 6 | bereda
# Processing Record 35 of Set 6 | ontario
# Processing Record 36 of Set 6 | deep river
# Processing Record 37 of Set 6 | nueva loja
# Processing Record 38 of Set 6 | manta
# Processing Record 39 of Set 6 | lundazi
# Processing Record 40 of Set 6 | togur
# Processing Record 41 of Set 6 | aripuana
# Processing Record 42 of Set 6 | altamira
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | comodoro rivadavia
# Processing Record 45 of Set 6 | aksha
# Processing Record 46 of Set 6 | mangrol
# Processing Record 47 of Set 6 | grand-santi
# Processing Record 48 of Set 6 | mackay
# Processing Record 49 of Set 6 | peniche
# Processing Record 50 of Set 6 | hamilton
# Processing Record 1 of Set 7 | iqaluit
# Processing Record 2 of Set 7 | port hardy
# Processing Record 3 of Set 7 | cururupu
# Processing Record 4 of Set 7 | sabya
# Processing Record 5 of Set 7 | estevan
# Processing Record 6 of Set 7 | clyde river
# Processing Record 7 of Set 7 | qasigiannguit
# Processing Record 8 of Set 7 | joshimath
# Processing Record 9 of Set 7 | tuatapere
# Processing Record 10 of Set 7 | mabaruma
# Processing Record 11 of Set 7 | nome
# Processing Record 12 of Set 7 | floro
# Processing Record 13 of Set 7 | djambala
# Processing Record 14 of Set 7 | mahebourg
# Processing Record 15 of Set 7 | hay river
# Processing Record 16 of Set 7 | valparaiso
# Processing Record 17 of Set 7 | dingle
# Processing Record 18 of Set 7 | port-gentil
# Processing Record 19 of Set 7 | colares
# Processing Record 20 of Set 7 | gardan diwal
# City not found. Skipping...
# Processing Record 21 of Set 7 | taoudenni
# Processing Record 22 of Set 7 | miri
# Processing Record 23 of Set 7 | ouango
# Processing Record 24 of Set 7 | jardim
# Processing Record 25 of Set 7 | lompoc
# Processing Record 26 of Set 7 | shakawe
# Processing Record 27 of Set 7 | bintulu
# Processing Record 28 of Set 7 | hami
# Processing Record 29 of Set 7 | padang
# Processing Record 30 of Set 7 | alice springs
# Processing Record 31 of Set 7 | vila
# Processing Record 32 of Set 7 | ellenabad
# Processing Record 33 of Set 7 | praia da vitoria
# Processing Record 34 of Set 7 | caravelas
# Processing Record 35 of Set 7 | constitucion
# Processing Record 36 of Set 7 | arraial do cabo
# Processing Record 37 of Set 7 | monroe
# Processing Record 38 of Set 7 | belaya gora
# Processing Record 39 of Set 7 | hambantota
# Processing Record 40 of Set 7 | vila velha
# Processing Record 41 of Set 7 | sabha
# Processing Record 42 of Set 7 | tamahu
# Processing Record 43 of Set 7 | cabo san lucas
# Processing Record 44 of Set 7 | nelson bay
# Processing Record 45 of Set 7 | shahi
# Processing Record 46 of Set 7 | chernyshevskiy
# Processing Record 47 of Set 7 | wasco
# Processing Record 48 of Set 7 | upernavik
# Processing Record 49 of Set 7 | washougal
# Processing Record 50 of Set 7 | elk plain
# Processing Record 1 of Set 8 | torbay
# Processing Record 2 of Set 8 | portland
# Processing Record 3 of Set 8 | atar
# Processing Record 4 of Set 8 | zhigansk
# Processing Record 5 of Set 8 | kavaratti
# Processing Record 6 of Set 8 | arlit
# Processing Record 7 of Set 8 | presidente medici
# Processing Record 8 of Set 8 | marsaxlokk
# Processing Record 9 of Set 8 | cortez
# Processing Record 10 of Set 8 | wyndham
# Processing Record 11 of Set 8 | matagami
# Processing Record 12 of Set 8 | paka
# Processing Record 13 of Set 8 | show low
# Processing Record 14 of Set 8 | udachnyy
# Processing Record 15 of Set 8 | albertville
# Processing Record 16 of Set 8 | rochester
# Processing Record 17 of Set 8 | hovd
# Processing Record 18 of Set 8 | pangai
# Processing Record 19 of Set 8 | shimizu
# Processing Record 20 of Set 8 | wewak
# Processing Record 21 of Set 8 | elmira
# Processing Record 22 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 8 | haines junction
# Processing Record 24 of Set 8 | tual
# Processing Record 25 of Set 8 | ajaccio
# Processing Record 26 of Set 8 | la ronge
# Processing Record 27 of Set 8 | aklavik
# Processing Record 28 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 8 | bubaque
# Processing Record 30 of Set 8 | xining
# Processing Record 31 of Set 8 | carlsbad
# Processing Record 32 of Set 8 | camacha
# Processing Record 33 of Set 8 | severo-kurilsk
# Processing Record 34 of Set 8 | nanortalik
# Processing Record 35 of Set 8 | castlemaine
# Processing Record 36 of Set 8 | kampene
# Processing Record 37 of Set 8 | praia
# Processing Record 38 of Set 8 | rawson
# Processing Record 39 of Set 8 | santa maria
# Processing Record 40 of Set 8 | araouane
# Processing Record 41 of Set 8 | marneuli
# Processing Record 42 of Set 8 | mitchell
# Processing Record 43 of Set 8 | kondinskoye
# Processing Record 44 of Set 8 | winnemucca
# Processing Record 45 of Set 8 | nguru
# Processing Record 46 of Set 8 | kracheh
# City not found. Skipping...
# Processing Record 47 of Set 8 | beamsville
# Processing Record 48 of Set 8 | alofi
# Processing Record 49 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 50 of Set 8 | kutum
# Processing Record 1 of Set 9 | niamey
# Processing Record 2 of Set 9 | veletma
# City not found. Skipping...
# Processing Record 3 of Set 9 | cockburn town
# Processing Record 4 of Set 9 | ilulissat
# Processing Record 5 of Set 9 | vardo
# Processing Record 6 of Set 9 | sobral
# Processing Record 7 of Set 9 | paamiut
# Processing Record 8 of Set 9 | mokolo
# Processing Record 9 of Set 9 | sidi ali
# Processing Record 10 of Set 9 | kamenicky senov
# Processing Record 11 of Set 9 | tautira
# Processing Record 12 of Set 9 | tambacounda
# Processing Record 13 of Set 9 | ballina
# Processing Record 14 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 9 | madaoua
# Processing Record 16 of Set 9 | montijo
# Processing Record 17 of Set 9 | diego de almagro
# Processing Record 18 of Set 9 | malyn
# Processing Record 19 of Set 9 | khorinsk
# Processing Record 20 of Set 9 | kimbe
# Processing Record 21 of Set 9 | nyurba
# Processing Record 22 of Set 9 | brae
# Processing Record 23 of Set 9 | andros town
# Processing Record 24 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 9 | matadi
# Processing Record 26 of Set 9 | pipri
# Processing Record 27 of Set 9 | lat yao
# Processing Record 28 of Set 9 | kargasok
# Processing Record 29 of Set 9 | babayurt
# Processing Record 30 of Set 9 | hualmay
# Processing Record 31 of Set 9 | stephenville
# Processing Record 32 of Set 9 | grindavik
# Processing Record 33 of Set 9 | pacific grove
# Processing Record 34 of Set 9 | cap malheureux
# Processing Record 35 of Set 9 | cedar city
# Processing Record 36 of Set 9 | otuzco
# Processing Record 37 of Set 9 | kysyl-syr
# Processing Record 38 of Set 9 | mayumba
# Processing Record 39 of Set 9 | moyale
# Processing Record 40 of Set 9 | moron
# Processing Record 41 of Set 9 | kurilsk
# Processing Record 42 of Set 9 | yenotayevka
# Processing Record 43 of Set 9 | palm coast
# Processing Record 44 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 9 | bolu
# Processing Record 46 of Set 9 | varkaus
# Processing Record 47 of Set 9 | talnakh
# Processing Record 48 of Set 9 | harper
# Processing Record 49 of Set 9 | ginir
# Processing Record 50 of Set 9 | nha trang
# Processing Record 1 of Set 10 | fort nelson
# Processing Record 2 of Set 10 | kloulklubed
# Processing Record 3 of Set 10 | ahipara
# Processing Record 4 of Set 10 | tamandare
# Processing Record 5 of Set 10 | isangel
# Processing Record 6 of Set 10 | zhaotong
# Processing Record 7 of Set 10 | rocha
# Processing Record 8 of Set 10 | wilmington
# Processing Record 9 of Set 10 | saint pete beach
# Processing Record 10 of Set 10 | sibiti
# Processing Record 11 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 12 of Set 10 | chuguyevka
# Processing Record 13 of Set 10 | rondonopolis
# Processing Record 14 of Set 10 | ust-ishim
# Processing Record 15 of Set 10 | kayes
# Processing Record 16 of Set 10 | cruden bay
# City not found. Skipping...
# Processing Record 17 of Set 10 | isla vista
# Processing Record 18 of Set 10 | inhambane
# Processing Record 19 of Set 10 | pringsewu
# Processing Record 20 of Set 10 | sungaipenuh
# Processing Record 21 of Set 10 | cabra
# Processing Record 22 of Set 10 | lorengau
# Processing Record 23 of Set 10 | polovinnoye
# Processing Record 24 of Set 10 | jacksonville
# Processing Record 25 of Set 10 | mayya
# Processing Record 26 of Set 10 | sao joao del rei
# Processing Record 27 of Set 10 | lebanon
# Processing Record 28 of Set 10 | manutuke
# Processing Record 29 of Set 10 | boissevain
# Processing Record 30 of Set 10 | saint-joseph
# Processing Record 31 of Set 10 | port hedland
# Processing Record 32 of Set 10 | kirakira
# Processing Record 33 of Set 10 | leninskoye
# Processing Record 34 of Set 10 | borlange
# City not found. Skipping...
# Processing Record 35 of Set 10 | gamba
# Processing Record 36 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 10 | xaltianguis
# Processing Record 38 of Set 10 | xihe
# Processing Record 39 of Set 10 | olafsvik
# Processing Record 40 of Set 10 | beringovskiy
# Processing Record 41 of Set 10 | alipur
# Processing Record 42 of Set 10 | bontang
# Processing Record 43 of Set 10 | macamic
# Processing Record 44 of Set 10 | castelu
# Processing Record 45 of Set 10 | darnah
# Processing Record 46 of Set 10 | sinop
# Processing Record 47 of Set 10 | nantucket
# Processing Record 48 of Set 10 | dongsheng
# Processing Record 49 of Set 10 | sri aman
# Processing Record 50 of Set 10 | jalu
# Processing Record 1 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 2 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 3 of Set 11 | adrar
# Processing Record 4 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 5 of Set 11 | itoman
# Processing Record 6 of Set 11 | san quintin
# Processing Record 7 of Set 11 | yumen
# Processing Record 8 of Set 11 | trelew
# Processing Record 9 of Set 11 | teya
# Processing Record 10 of Set 11 | kalakamati
# Processing Record 11 of Set 11 | kalety
# Processing Record 12 of Set 11 | lagoa
# Processing Record 13 of Set 11 | narvik
# Processing Record 14 of Set 11 | cuiluan
# Processing Record 15 of Set 11 | gwanda
# Processing Record 16 of Set 11 | seydi
# Processing Record 17 of Set 11 | sivaki
# Processing Record 18 of Set 11 | san ramon
# Processing Record 19 of Set 11 | beloha
# Processing Record 20 of Set 11 | kodinsk
# Processing Record 21 of Set 11 | marzuq
# Processing Record 22 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 11 | burica
# City not found. Skipping...
# Processing Record 24 of Set 11 | vieste
# Processing Record 25 of Set 11 | nago
# Processing Record 26 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 27 of Set 11 | mount gambier
# Processing Record 28 of Set 11 | keflavik
# Processing Record 29 of Set 11 | dali
# Processing Record 30 of Set 11 | artvin
# Processing Record 31 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 32 of Set 11 | tortoli
# Processing Record 33 of Set 11 | naples
# Processing Record 34 of Set 11 | luwuk
# Processing Record 35 of Set 11 | kontagora
# Processing Record 36 of Set 11 | popondetta
# Processing Record 37 of Set 11 | antissa
# City not found. Skipping...
# Processing Record 38 of Set 11 | scottsbluff
# Processing Record 39 of Set 11 | marsa matruh
# Processing Record 40 of Set 11 | natal
# Processing Record 41 of Set 11 | kishapu
# Processing Record 42 of Set 11 | liyang
# Processing Record 43 of Set 11 | sorong
# Processing Record 44 of Set 11 | severnyy
# Processing Record 45 of Set 11 | kapoeta
# Processing Record 46 of Set 11 | atherton
# Processing Record 47 of Set 11 | lakatoro
# Processing Record 48 of Set 11 | naryan-mar
# Processing Record 49 of Set 11 | lufilufi
# Processing Record 50 of Set 11 | fairbanks
# Processing Record 1 of Set 12 | ystad
# Processing Record 2 of Set 12 | pasighat
# Processing Record 3 of Set 12 | itabira
# Processing Record 4 of Set 12 | atambua
# Processing Record 5 of Set 12 | qesarya
# Processing Record 6 of Set 12 | tilichiki
# Processing Record 7 of Set 12 | siavonga
# Processing Record 8 of Set 12 | bibbiena
# Processing Record 9 of Set 12 | champerico
# Processing Record 10 of Set 12 | labuhan
# Processing Record 11 of Set 12 | pilar
# Processing Record 12 of Set 12 | asfi
# Processing Record 13 of Set 12 | acapulco
# Processing Record 14 of Set 12 | naron
# Processing Record 15 of Set 12 | ambovombe
# Processing Record 16 of Set 12 | bonthe
# Processing Record 17 of Set 12 | zolotinka
# City not found. Skipping...
# Processing Record 18 of Set 12 | bilibino
# Processing Record 19 of Set 12 | eseka
# Processing Record 20 of Set 12 | tonj
# Processing Record 21 of Set 12 | aginskoye
# Processing Record 22 of Set 12 | bosaso
# Processing Record 23 of Set 12 | beyneu
# Processing Record 24 of Set 12 | port-de-paix
# City not found. Skipping...
# Processing Record 25 of Set 12 | luganville
# Processing Record 26 of Set 12 | phan thiet
# Processing Record 27 of Set 12 | atyrau
# Processing Record 28 of Set 12 | arroyo
# Processing Record 29 of Set 12 | muleba
# Processing Record 30 of Set 12 | troitskoye
# Processing Record 31 of Set 12 | laukaa
# Processing Record 32 of Set 12 | yerbogachen
# Processing Record 33 of Set 12 | tondano
# Processing Record 34 of Set 12 | curuguaty
# Processing Record 35 of Set 12 | lincoln
# Processing Record 36 of Set 12 | mukhen
# Processing Record 37 of Set 12 | dryden
# Processing Record 38 of Set 12 | mazatlan
# Processing Record 39 of Set 12 | bundaberg
# Processing Record 40 of Set 12 | tateyama
# Processing Record 41 of Set 12 | buin
# Processing Record 42 of Set 12 | alizai
# Processing Record 43 of Set 12 | belmonte
# Processing Record 44 of Set 12 | marasu
# Processing Record 45 of Set 12 | metsavan
# Processing Record 46 of Set 12 | ca mau
# Processing Record 47 of Set 12 | shetpe
# Processing Record 48 of Set 12 | marfino
# Processing Record 49 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 50 of Set 12 | owatonna
# Processing Record 1 of Set 13 | shelburne
# Processing Record 2 of Set 13 | north bend
# Processing Record 3 of Set 13 | sarangani
# Processing Record 4 of Set 13 | benevento
# Processing Record 5 of Set 13 | aksarka
# Processing Record 6 of Set 13 | sarakhs
# Processing Record 7 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 13 | ayagoz
# Processing Record 9 of Set 13 | balkanabat
# Processing Record 10 of Set 13 | qujing
# Processing Record 11 of Set 13 | deputatskiy
# Processing Record 12 of Set 13 | kaka
# Processing Record 13 of Set 13 | elbistan
# Processing Record 14 of Set 13 | myitkyina
# Processing Record 15 of Set 13 | acarau
# Processing Record 16 of Set 13 | svetlaya
# Processing Record 17 of Set 13 | quelimane
# Processing Record 18 of Set 13 | aykhal
# Processing Record 19 of Set 13 | saint anthony
# Processing Record 20 of Set 13 | markova
# Processing Record 21 of Set 13 | duz
# City not found. Skipping...
# Processing Record 22 of Set 13 | namatanai
# Processing Record 23 of Set 13 | drovyanaya
# Processing Record 24 of Set 13 | imbituba
# Processing Record 25 of Set 13 | olga
# Processing Record 26 of Set 13 | omboue
# Processing Record 27 of Set 13 | mugur-aksy
# Processing Record 28 of Set 13 | sale
# Processing Record 29 of Set 13 | santiago del estero
# Processing Record 30 of Set 13 | ishigaki
# Processing Record 31 of Set 13 | itaituba
# Processing Record 32 of Set 13 | husavik
# Processing Record 33 of Set 13 | ganzhou
# Processing Record 34 of Set 13 | itacare
# Processing Record 35 of Set 13 | yangliuqing
# Processing Record 36 of Set 13 | lublin
# Processing Record 37 of Set 13 | strzelce krajenskie
# Processing Record 38 of Set 13 | nizwa
# Processing Record 39 of Set 13 | turukhansk
# Processing Record 40 of Set 13 | alta floresta
# Processing Record 41 of Set 13 | dire dawa
# Processing Record 42 of Set 13 | gazojak
# Processing Record 43 of Set 13 | abut
# Processing Record 44 of Set 13 | wajima
# Processing Record 45 of Set 13 | nishihara
# Processing Record 46 of Set 13 | volginskiy
# City not found. Skipping...
# Processing Record 47 of Set 13 | puerto asis
# Processing Record 48 of Set 13 | rapid valley
# Processing Record 49 of Set 13 | russell
# Processing Record 50 of Set 13 | palauig
# Processing Record 1 of Set 14 | noumea
# Processing Record 2 of Set 14 | kupang
# Processing Record 3 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 4 of Set 14 | stolin
# Processing Record 5 of Set 14 | alangayam
# Processing Record 6 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 7 of Set 14 | san antonio
# Processing Record 8 of Set 14 | kang
# Processing Record 9 of Set 14 | zubtsov
# Processing Record 10 of Set 14 | mizdah
# Processing Record 11 of Set 14 | babol
# Processing Record 12 of Set 14 | taitung
# Processing Record 13 of Set 14 | sur
# Processing Record 14 of Set 14 | hazorasp
# Processing Record 15 of Set 14 | nykoping
# Processing Record 16 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 17 of Set 14 | uzumlu
# City not found. Skipping...
# Processing Record 18 of Set 14 | bachaquero
# Processing Record 19 of Set 14 | nouadhibou
# Processing Record 20 of Set 14 | antalaha
# Processing Record 21 of Set 14 | bloomingdale
# Processing Record 22 of Set 14 | tayoltita
# Processing Record 23 of Set 14 | batticaloa
# Processing Record 24 of Set 14 | kuching
# Processing Record 25 of Set 14 | roma
# Processing Record 26 of Set 14 | mana
# Processing Record 27 of Set 14 | salym
# Processing Record 28 of Set 14 | leiyang
# Processing Record 29 of Set 14 | boffa
# Processing Record 30 of Set 14 | ferrol
# Processing Record 31 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 32 of Set 14 | kiri buru
# Processing Record 33 of Set 14 | berlevag
# Processing Record 34 of Set 14 | ramasukha
# City not found. Skipping...
# Processing Record 35 of Set 14 | omaha
# Processing Record 36 of Set 14 | payo
# Processing Record 37 of Set 14 | mogadishu
# Processing Record 38 of Set 14 | chulman
# Processing Record 39 of Set 14 | luang prabang
# Processing Record 40 of Set 14 | cumbitara
# Processing Record 41 of Set 14 | tanshui
# City not found. Skipping...
# Processing Record 42 of Set 14 | samarai
# Processing Record 43 of Set 14 | matto
# City not found. Skipping...
# Processing Record 44 of Set 14 | mayo
# Processing Record 45 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 14 | iracoubo
# Processing Record 47 of Set 14 | honiara
# Processing Record 48 of Set 14 | ust-shonosha
# Processing Record 49 of Set 14 | jaisalmer
# Processing Record 50 of Set 14 | oussouye
# Processing Record 1 of Set 15 | leshukonskoye
# Processing Record 2 of Set 15 | dese
# Processing Record 3 of Set 15 | turayf
# Processing Record 4 of Set 15 | sola
# Processing Record 5 of Set 15 | tibagon
# Processing Record 6 of Set 15 | tikrit
# Processing Record 7 of Set 15 | abu samrah
# Processing Record 8 of Set 15 | santa rosa
# Processing Record 9 of Set 15 | matara
# Processing Record 10 of Set 15 | geraldton
# Processing Record 11 of Set 15 | middelburg
# Processing Record 12 of Set 15 | aviles
# Processing Record 13 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 15 | pereleshino
# Processing Record 15 of Set 15 | mezhdurechensk
# Processing Record 16 of Set 15 | mikuni
# Processing Record 17 of Set 15 | iki-burul
# Processing Record 18 of Set 15 | menongue
# Processing Record 19 of Set 15 | umm lajj
# Processing Record 20 of Set 15 | buta
# Processing Record 21 of Set 15 | udayagiri
# Processing Record 22 of Set 15 | hyeres
# Processing Record 23 of Set 15 | birjand
# Processing Record 24 of Set 15 | iquique
# Processing Record 25 of Set 15 | miranorte
# City not found. Skipping...
# Processing Record 26 of Set 15 | jinchengjiang
# City not found. Skipping...
# Processing Record 27 of Set 15 | cascais
# Processing Record 28 of Set 15 | carora
# Processing Record 29 of Set 15 | dunedin
# Processing Record 30 of Set 15 | kosonsoy
# Processing Record 31 of Set 15 | cuauhtemoc
# Processing Record 32 of Set 15 | almaty
# Processing Record 33 of Set 15 | santa paula
# Processing Record 34 of Set 15 | menomonie
# Processing Record 35 of Set 15 | ulaanbaatar
# Processing Record 36 of Set 15 | la asuncion
# Processing Record 37 of Set 15 | santa fe
# Processing Record 38 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 15 | tabukiniberu
# City not found. Skipping...
# Processing Record 40 of Set 15 | traverse city
# Processing Record 41 of Set 15 | hare bay
# Processing Record 42 of Set 15 | karratha
# Processing Record 43 of Set 15 | snyder
# Processing Record 44 of Set 15 | nanyang
# Processing Record 45 of Set 15 | manturovo
# Processing Record 46 of Set 15 | waipawa
# Processing Record 47 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 15 | cabildo
# Processing Record 49 of Set 15 | porto novo
# Processing Record 50 of Set 15 | bolivar
# Processing Record 1 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 16 | rotherham
# Processing Record 3 of Set 16 | roald
# Processing Record 4 of Set 16 | nioro
# Processing Record 5 of Set 16 | nizhniy tsasuchey
# Processing Record 6 of Set 16 | ecuandureo
# Processing Record 7 of Set 16 | braganca
# Processing Record 8 of Set 16 | phalaborwa
# Processing Record 9 of Set 16 | higuey
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 694

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Avera  33.1940  -82.5271     64.45        59         100
# 1        Ankara  39.9199   32.8543     56.59        86          75
# 2        Hailar  49.2000  119.7000     38.35        26           3
# 3  Kruisfontein -34.0033   24.7314     73.89        50           6
# 4        Albany  42.6001  -73.9662     46.35        84         100
# 5      Khatanga  71.9667  102.5000     22.87        97         100
# 6     Cape Town -33.9258   18.4232     69.39        70          75
# 7         Pisco -13.7000  -76.2167     57.25        94           2
# 8       Ushuaia -54.8000  -68.3000     42.46        70           0
# 9      Malegaon  20.5500   74.5333     82.60        65          91
#
#    Wind Speed Country                 Date      Description
# 0        7.23      US  2022-10-17 07:43:35  overcast clouds
# 1        9.22      TR  2022-10-17 07:44:17    broken clouds
# 2       12.15      CN  2022-10-17 07:44:38        clear sky
# 3        9.28      ZA  2022-10-17 07:44:38        clear sky
# 4        2.80      US  2022-10-17 07:44:39  overcast clouds
# 5        6.22      RU  2022-10-17 07:44:39       light snow
# 6       11.50      ZA  2022-10-17 07:42:41    broken clouds
# 7        6.91      PE  2022-10-17 07:44:40        clear sky
# 8        9.22      AR  2022-10-17 07:44:00        clear sky
# 9        6.96      IN  2022-10-17 07:44:41  overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Description"]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

city_data_df=city_data_df[new_column_order]

# Display sample data
# YOUR CODE HERE

city_data_df.tail()
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 689              Nioro      GM  13.3500  -15.7500     76.39        88
# 690  Nizhniy Tsasuchey      RU  50.5167  115.1333     41.47        27
# 691         Ecuandureo      MX  20.1667 -102.1833     60.55        84
# 692           Braganca      BR  -1.0536  -46.7656     75.27        89
# 693         Phalaborwa      ZA -23.9430   31.1411     79.16        51
#
#      Cloudiness  Wind Speed      Description
# 689          96        0.54  overcast clouds
# 690           0        5.75        clear sky
# 691         100        2.26  overcast clouds
# 692          71        1.99    broken clouds
# 693          97        1.68  overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE

city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

output_data_file = "weather_database/WeatherPy_Database.csv"


# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE


city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22260\2723434492.py in <module>
#       9
#      10
# ---> 11 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weather_database/WeatherPy_Database.csv'
