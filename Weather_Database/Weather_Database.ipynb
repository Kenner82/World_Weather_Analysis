# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# %%
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 759

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE  
        
             
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            
        # Append the city information into the city_data list
        # YOUR CODE HERE
        
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avera
# Processing Record 2 of Set 1 | ankara
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | hailar
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | pisco
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | malegaon
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | voyvozh
# Processing Record 14 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 1 | kaeo
# Processing Record 16 of Set 1 | amapa
# Processing Record 17 of Set 1 | mahibadhoo
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | bandarbeyla
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | tairua
# Processing Record 22 of Set 1 | skelleftea
# Processing Record 23 of Set 1 | guerrero negro
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | vista hermosa
# Processing Record 26 of Set 1 | filingue
# Processing Record 27 of Set 1 | hofn
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | ayan
# Processing Record 31 of Set 1 | faanui
# Processing Record 32 of Set 1 | ponta do sol
# Processing Record 33 of Set 1 | tambopata
# Processing Record 34 of Set 1 | cayenne
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | dikson
# Processing Record 40 of Set 1 | biasca
# Processing Record 41 of Set 1 | necochea
# Processing Record 42 of Set 1 | kavieng
# Processing Record 43 of Set 1 | brumadinho
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | athabasca
# Processing Record 47 of Set 1 | solin
# Processing Record 48 of Set 1 | meulaboh
# Processing Record 49 of Set 1 | chokurdakh
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | sorland
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | panguna
# Processing Record 5 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | rosamorada
# Processing Record 8 of Set 2 | ixtapa
# Processing Record 9 of Set 2 | port lincoln
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 2 | vanimo
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | marabba
# Processing Record 17 of Set 2 | kattivakkam
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | elizabeth city
# Processing Record 20 of Set 2 | norman wells
# Processing Record 21 of Set 2 | nouakchott
# Processing Record 22 of Set 2 | oksfjord
# Processing Record 23 of Set 2 | migori
# Processing Record 24 of Set 2 | lebu
# Processing Record 25 of Set 2 | saskylakh
# Processing Record 26 of Set 2 | pitimbu
# Processing Record 27 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 2 | thunder bay
# Processing Record 29 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 2 | feijo
# Processing Record 31 of Set 2 | lavrentiya
# Processing Record 32 of Set 2 | outlook
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | samarinda
# Processing Record 36 of Set 2 | fortuna
# Processing Record 37 of Set 2 | nara
# Processing Record 38 of Set 2 | luderitz
# Processing Record 39 of Set 2 | chuy
# Processing Record 40 of Set 2 | puerto cabezas
# Processing Record 41 of Set 2 | khani
# Processing Record 42 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 2 | kahului
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | tucuman
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | nemuro
# Processing Record 49 of Set 2 | san pedro
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | faya
# Processing Record 2 of Set 3 | tsibanobalka
# Processing Record 3 of Set 3 | codrington
# Processing Record 4 of Set 3 | topolobampo
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | flinders
# Processing Record 7 of Set 3 | del rio
# Processing Record 8 of Set 3 | viedma
# Processing Record 9 of Set 3 | innisfail
# Processing Record 10 of Set 3 | barpeta
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | salalah
# Processing Record 13 of Set 3 | hervey bay
# Processing Record 14 of Set 3 | hobart
# Processing Record 15 of Set 3 | vrbove
# Processing Record 16 of Set 3 | san patricio
# Processing Record 17 of Set 3 | touros
# Processing Record 18 of Set 3 | tiksi
# Processing Record 19 of Set 3 | tsiroanomandidy
# Processing Record 20 of Set 3 | kyzyl-suu
# Processing Record 21 of Set 3 | bengkulu
# Processing Record 22 of Set 3 | saint-augustin
# Processing Record 23 of Set 3 | kushima
# Processing Record 24 of Set 3 | san luis
# Processing Record 25 of Set 3 | kasongo-lunda
# Processing Record 26 of Set 3 | am timan
# Processing Record 27 of Set 3 | atuona
# Processing Record 28 of Set 3 | san juan
# Processing Record 29 of Set 3 | sitka
# Processing Record 30 of Set 3 | podor
# Processing Record 31 of Set 3 | ito
# Processing Record 32 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 3 | klaksvik
# Processing Record 34 of Set 3 | vaini
# Processing Record 35 of Set 3 | salinas
# Processing Record 36 of Set 3 | santa luzia
# Processing Record 37 of Set 3 | guipavas
# Processing Record 38 of Set 3 | constantine
# Processing Record 39 of Set 3 | port alfred
# Processing Record 40 of Set 3 | carutapera
# Processing Record 41 of Set 3 | kodiak
# Processing Record 42 of Set 3 | ostrovnoy
# Processing Record 43 of Set 3 | laguna
# Processing Record 44 of Set 3 | saint-philippe
# Processing Record 45 of Set 3 | xuzhou
# Processing Record 46 of Set 3 | likasi
# Processing Record 47 of Set 3 | linxia
# Processing Record 48 of Set 3 | hermanus
# Processing Record 49 of Set 3 | svetlogorsk
# Processing Record 50 of Set 3 | husainabad
# Processing Record 1 of Set 4 | jumla
# Processing Record 2 of Set 4 | coos bay
# Processing Record 3 of Set 4 | axim
# Processing Record 4 of Set 4 | mangai
# Processing Record 5 of Set 4 | mont-de-marsan
# Processing Record 6 of Set 4 | aswan
# Processing Record 7 of Set 4 | komsomolskiy
# Processing Record 8 of Set 4 | quatre cocos
# Processing Record 9 of Set 4 | camopi
# Processing Record 10 of Set 4 | coahuayana
# Processing Record 11 of Set 4 | souillac
# Processing Record 12 of Set 4 | sattenapalle
# Processing Record 13 of Set 4 | avarua
# Processing Record 14 of Set 4 | kiruna
# Processing Record 15 of Set 4 | tuxpan
# Processing Record 16 of Set 4 | airai
# Processing Record 17 of Set 4 | wanning
# Processing Record 18 of Set 4 | beira
# Processing Record 19 of Set 4 | coquimbo
# Processing Record 20 of Set 4 | hluti
# Processing Record 21 of Set 4 | tanda
# Processing Record 22 of Set 4 | dakar
# Processing Record 23 of Set 4 | rumoi
# Processing Record 24 of Set 4 | canton
# Processing Record 25 of Set 4 | jamestown
# Processing Record 26 of Set 4 | hasaki
# Processing Record 27 of Set 4 | esperance
# Processing Record 28 of Set 4 | vestmannaeyjar
# Processing Record 29 of Set 4 | yarada
# Processing Record 30 of Set 4 | jawhar
# Processing Record 31 of Set 4 | dvurechensk
# Processing Record 32 of Set 4 | nadym
# Processing Record 33 of Set 4 | mitu
# Processing Record 34 of Set 4 | stawell
# Processing Record 35 of Set 4 | mandali
# Processing Record 36 of Set 4 | hithadhoo
# Processing Record 37 of Set 4 | nalut
# Processing Record 38 of Set 4 | port elizabeth
# Processing Record 39 of Set 4 | kusti
# Processing Record 40 of Set 4 | mehamn
# Processing Record 41 of Set 4 | baruun-urt
# Processing Record 42 of Set 4 | tiarei
# Processing Record 43 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 4 | ancud
# Processing Record 46 of Set 4 | qeshm
# Processing Record 47 of Set 4 | katsuura
# Processing Record 48 of Set 4 | nhulunbuy
# Processing Record 49 of Set 4 | unity
# Processing Record 50 of Set 4 | muros
# Processing Record 1 of Set 5 | thinadhoo
# Processing Record 2 of Set 5 | carnarvon
# Processing Record 3 of Set 5 | victoria
# Processing Record 4 of Set 5 | san cristobal
# Processing Record 5 of Set 5 | westport
# Processing Record 6 of Set 5 | tasiilaq
# Processing Record 7 of Set 5 | verdalsora
# City not found. Skipping...
# Processing Record 8 of Set 5 | te anau
# Processing Record 9 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 5 | choix
# Processing Record 11 of Set 5 | sinnamary
# Processing Record 12 of Set 5 | amuntai
# Processing Record 13 of Set 5 | liverpool
# Processing Record 14 of Set 5 | castro
# Processing Record 15 of Set 5 | ovalle
# Processing Record 16 of Set 5 | haapiti
# Processing Record 17 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 18 of Set 5 | saint-pierre
# Processing Record 19 of Set 5 | becerril
# Processing Record 20 of Set 5 | kourou
# Processing Record 21 of Set 5 | gat
# Processing Record 22 of Set 5 | leningradskiy
# Processing Record 23 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 5 | trairi
# Processing Record 25 of Set 5 | valdivia
# Processing Record 26 of Set 5 | norrtalje
# Processing Record 27 of Set 5 | kayerkan
# Processing Record 28 of Set 5 | seoul
# Processing Record 29 of Set 5 | ventspils
# Processing Record 30 of Set 5 | saint george
# Processing Record 31 of Set 5 | pevek
# Processing Record 32 of Set 5 | bethel
# Processing Record 33 of Set 5 | ponta delgada
# Processing Record 34 of Set 5 | of
# City not found. Skipping...
# Processing Record 35 of Set 5 | lima
# Processing Record 36 of Set 5 | riverton
# Processing Record 37 of Set 5 | millbrook
# Processing Record 38 of Set 5 | leander
# Processing Record 39 of Set 5 | springdale
# Processing Record 40 of Set 5 | khasan
# Processing Record 41 of Set 5 | sinegorye
# Processing Record 42 of Set 5 | kalmunai
# Processing Record 43 of Set 5 | vestmanna
# Processing Record 44 of Set 5 | flin flon
# Processing Record 45 of Set 5 | ngunguru
# Processing Record 46 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 5 | kyra
# Processing Record 49 of Set 5 | bathsheba
# Processing Record 50 of Set 5 | college
# Processing Record 1 of Set 6 | tabou
# Processing Record 2 of Set 6 | narsaq
# Processing Record 3 of Set 6 | novyy urgal
# Processing Record 4 of Set 6 | monrovia
# Processing Record 5 of Set 6 | nuqui
# Processing Record 6 of Set 6 | hobyo
# Processing Record 7 of Set 6 | los llanos de aridane
# Processing Record 8 of Set 6 | marawi
# Processing Record 9 of Set 6 | srednekolymsk
# Processing Record 10 of Set 6 | terney
# Processing Record 11 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 6 | los alamos
# Processing Record 13 of Set 6 | yulara
# Processing Record 14 of Set 6 | lahat
# Processing Record 15 of Set 6 | port macquarie
# Processing Record 16 of Set 6 | saldanha
# Processing Record 17 of Set 6 | sendafa
# Processing Record 18 of Set 6 | erdenet
# Processing Record 19 of Set 6 | bjornevatn
# Processing Record 20 of Set 6 | chifeng
# Processing Record 21 of Set 6 | awka
# Processing Record 22 of Set 6 | thompson
# Processing Record 23 of Set 6 | verkhnevilyuysk
# Processing Record 24 of Set 6 | sao filipe
# Processing Record 25 of Set 6 | margate
# Processing Record 26 of Set 6 | balkhash
# Processing Record 27 of Set 6 | moindou
# Processing Record 28 of Set 6 | naze
# Processing Record 29 of Set 6 | boa vista
# Processing Record 30 of Set 6 | nicoya
# Processing Record 31 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 6 | limbang
# Processing Record 33 of Set 6 | ponazyrevo
# Processing Record 34 of Set 6 | bereda
# Processing Record 35 of Set 6 | ontario
# Processing Record 36 of Set 6 | deep river
# Processing Record 37 of Set 6 | nueva loja
# Processing Record 38 of Set 6 | manta
# Processing Record 39 of Set 6 | lundazi
# Processing Record 40 of Set 6 | togur
# Processing Record 41 of Set 6 | aripuana
# Processing Record 42 of Set 6 | altamira
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | comodoro rivadavia
# Processing Record 45 of Set 6 | aksha
# Processing Record 46 of Set 6 | mangrol
# Processing Record 47 of Set 6 | grand-santi
# Processing Record 48 of Set 6 | mackay
# Processing Record 49 of Set 6 | peniche
# Processing Record 50 of Set 6 | hamilton
# Processing Record 1 of Set 7 | iqaluit
# Processing Record 2 of Set 7 | port hardy
# Processing Record 3 of Set 7 | cururupu
# Processing Record 4 of Set 7 | sabya
# Processing Record 5 of Set 7 | estevan
# Processing Record 6 of Set 7 | clyde river
# Processing Record 7 of Set 7 | qasigiannguit
# Processing Record 8 of Set 7 | joshimath
# Processing Record 9 of Set 7 | tuatapere
# Processing Record 10 of Set 7 | mabaruma
# Processing Record 11 of Set 7 | nome
# Processing Record 12 of Set 7 | floro
# Processing Record 13 of Set 7 | djambala
# Processing Record 14 of Set 7 | mahebourg
# Processing Record 15 of Set 7 | hay river
# Processing Record 16 of Set 7 | valparaiso
# Processing Record 17 of Set 7 | dingle
# Processing Record 18 of Set 7 | port-gentil
# Processing Record 19 of Set 7 | colares
# Processing Record 20 of Set 7 | gardan diwal
# City not found. Skipping...
# Processing Record 21 of Set 7 | taoudenni
# Processing Record 22 of Set 7 | miri
# Processing Record 23 of Set 7 | ouango
# Processing Record 24 of Set 7 | jardim
# Processing Record 25 of Set 7 | lompoc
# Processing Record 26 of Set 7 | shakawe
# Processing Record 27 of Set 7 | bintulu
# Processing Record 28 of Set 7 | hami
# Processing Record 29 of Set 7 | padang
# Processing Record 30 of Set 7 | alice springs
# Processing Record 31 of Set 7 | vila
# Processing Record 32 of Set 7 | ellenabad
# Processing Record 33 of Set 7 | praia da vitoria
# Processing Record 34 of Set 7 | caravelas
# Processing Record 35 of Set 7 | constitucion
# Processing Record 36 of Set 7 | arraial do cabo
# Processing Record 37 of Set 7 | monroe
# Processing Record 38 of Set 7 | belaya gora
# Processing Record 39 of Set 7 | hambantota
# Processing Record 40 of Set 7 | vila velha
# Processing Record 41 of Set 7 | sabha
# Processing Record 42 of Set 7 | tamahu
# Processing Record 43 of Set 7 | cabo san lucas
# Processing Record 44 of Set 7 | nelson bay
# Processing Record 45 of Set 7 | shahi
# Processing Record 46 of Set 7 | chernyshevskiy
# Processing Record 47 of Set 7 | wasco
# Processing Record 48 of Set 7 | upernavik
# Processing Record 49 of Set 7 | washougal
# Processing Record 50 of Set 7 | elk plain
# Processing Record 1 of Set 8 | torbay
# Processing Record 2 of Set 8 | portland
# Processing Record 3 of Set 8 | atar
# Processing Record 4 of Set 8 | zhigansk
# Processing Record 5 of Set 8 | kavaratti
# Processing Record 6 of Set 8 | arlit
# Processing Record 7 of Set 8 | presidente medici
# Processing Record 8 of Set 8 | marsaxlokk
# Processing Record 9 of Set 8 | cortez
# Processing Record 10 of Set 8 | wyndham
# Processing Record 11 of Set 8 | matagami
# Processing Record 12 of Set 8 | paka
# Processing Record 13 of Set 8 | show low
# Processing Record 14 of Set 8 | udachnyy
# Processing Record 15 of Set 8 | albertville
# Processing Record 16 of Set 8 | rochester
# Processing Record 17 of Set 8 | hovd
# Processing Record 18 of Set 8 | pangai
# Processing Record 19 of Set 8 | shimizu
# Processing Record 20 of Set 8 | wewak
# Processing Record 21 of Set 8 | elmira
# Processing Record 22 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 8 | haines junction
# Processing Record 24 of Set 8 | tual
# Processing Record 25 of Set 8 | ajaccio
# Processing Record 26 of Set 8 | la ronge
# Processing Record 27 of Set 8 | aklavik
# Processing Record 28 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 8 | bubaque
# Processing Record 30 of Set 8 | xining
# Processing Record 31 of Set 8 | carlsbad
# Processing Record 32 of Set 8 | camacha
# Processing Record 33 of Set 8 | severo-kurilsk
# Processing Record 34 of Set 8 | nanortalik
# Processing Record 35 of Set 8 | castlemaine
# Processing Record 36 of Set 8 | kampene
# Processing Record 37 of Set 8 | praia
# Processing Record 38 of Set 8 | rawson
# Processing Record 39 of Set 8 | santa maria
# Processing Record 40 of Set 8 | araouane
# Processing Record 41 of Set 8 | marneuli
# Processing Record 42 of Set 8 | mitchell
# Processing Record 43 of Set 8 | kondinskoye
# Processing Record 44 of Set 8 | winnemucca
# Processing Record 45 of Set 8 | nguru
# Processing Record 46 of Set 8 | kracheh
# City not found. Skipping...
# Processing Record 47 of Set 8 | beamsville
# Processing Record 48 of Set 8 | alofi
# Processing Record 49 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 50 of Set 8 | kutum

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 691

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = # YOUR CODE HERE

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0            Bluff -46.6000  168.3333     56.80          few clouds        68
# 1            Metro  -5.1131  105.3067     88.48     overcast clouds        54
# 2    Pacific Grove  36.6177 -121.9166     64.08           clear sky        87
# 3     Saint George  37.1041 -113.5841     79.95           clear sky        40
# 4          Mataura -46.1927  168.8643     56.48          few clouds        56
# 5          Biltine  14.5333   20.9167     80.42    scattered clouds        61
# 6              Gao  16.6362    1.6370     85.73       broken clouds        47
# 7        Hithadhoo  -0.6000   73.0833     82.00    scattered clouds        72
# 8  Bambous Virieux -20.3428   57.7575     76.21       broken clouds        78
# 9          Rikitea -23.1203 -134.9692     73.35           clear sky        72
#
#    Cloudiness  Wind Speed Country
# 0          21        2.28      NZ
# 1          92        4.52      ID
# 2           0        4.61      US
# 3           0       10.36      US
# 4          15        2.44      NZ
# 5          27        3.36      TD
# 6          77        6.31      ML
# 7          47        7.78      MV
# 8          75       13.80      MU
# 9           3       14.23      PF

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff      NZ -46.6000  168.3333     56.80        68          21
# 1            Metro      ID  -5.1131  105.3067     88.48        54          92
# 2    Pacific Grove      US  36.6177 -121.9166     64.08        87           0
# 3     Saint George      US  37.1041 -113.5841     79.95        40           0
# 4          Mataura      NZ -46.1927  168.8643     56.48        56          15
# 5          Biltine      TD  14.5333   20.9167     80.42        61          27
# 6              Gao      ML  16.6362    1.6370     85.73        47          77
# 7        Hithadhoo      MV  -0.6000   73.0833     82.00        72          47
# 8  Bambous Virieux      MU -20.3428   57.7575     76.21        78          75
# 9          Rikitea      PF -23.1203 -134.9692     73.35        72           3
#
#    Wind Speed Current Description
# 0        2.28          few clouds
# 1        4.52     overcast clouds
# 2        4.61           clear sky
# 3       10.36           clear sky
# 4        2.44          few clouds
# 5        3.36    scattered clouds
# 6        6.31       broken clouds
# 7        7.78    scattered clouds
# 8       13.80       broken clouds
# 9       14.23           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
